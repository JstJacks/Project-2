# 2021-02-19                                  -0.1548     0.107     0.759
# 2020-12-20 09:24:37                          0.0000     0.000     1.000
# 2020-12-20 08:21:25                          0.4404     0.592     0.408
# 2020-11-16 22:02:51                          0.0000     0.000     1.000
# 2020-05-15 22:51:44                          0.0000     0.000     1.000
# 2020-05-15 22:03:01                          0.5859     0.242     0.758
# 2020-05-01 22:44:56                          0.0000     0.000     1.000
# 2020-05-01 22:34:24                          0.0000     0.000     1.000
# 2020-01-10 06:58:23                          0.0000     0.000     1.000
# 2020-01-10 06:53:10                         -0.3412     0.000     0.555
# 2018-10-22 23:51:15                          0.0000     0.000     1.000
# 2018-10-22 23:51:15                          0.0000     0.000     1.000
# 2018-10-22 23:51:15                          0.0000     0.000     1.000
#
#                      text_neg  text_sent
# date
# 2021-11-20              0.595         -1
# 2021-10-24              0.000          1
# 2021-10-24              0.158         -1
# 2021-07-29              0.000          0
# 2021-07-19              0.000          1
# 2021-07-19              0.000          0
# 2021-06-25              0.376         -1
# 2021-06-25              0.189         -1
# 2021-06-25              0.000          1
# 2021-06-17              0.000          0
# 2021-06-13              0.000          1
# 2021-06-05              0.000          1
# 2021-06-04              0.000          0
# 2021-05-24              0.000          1
# 2021-05-21              0.000          1
# 2021-05-17              0.000          0
# 2021-05-16              0.124         -1
# 2021-05-16              0.000          0
# 2021-05-13              0.000          0
# 2021-04-27              0.115         -1
# 2021-03-24              0.167         -1
# 2021-03-24              0.000          0
# 2021-03-24              0.000          0
# 2021-03-12              0.247         -1
# 2021-02-19              0.164         -1
# 2021-02-19              0.134         -1
# 2020-12-20 09:24:37     0.000          0
# 2020-12-20 08:21:25     0.000          1
# 2020-11-16 22:02:51     0.000          0
# 2020-05-15 22:51:44     0.000          0
# 2020-05-15 22:03:01     0.000          1
# 2020-05-01 22:44:56     0.000          0
# 2020-05-01 22:34:24     0.000          0
# 2020-01-10 06:58:23     0.000          0
# 2020-01-10 06:53:10     0.445         -1
# 2018-10-22 23:51:15     0.000          0
# 2018-10-22 23:51:15     0.000          0
# 2018-10-22 23:51:15     0.000          0

# %%
# General Population Ethereum Sentiment Analysis

generalpop_ethereum_sentiment_analysis_bigdataset = Path("../Twitter_API/Twitter_API/Results/generalpop_ethereum_sentiment_analysis_bigdataset.csv")
generalpop_ethereum_sentiment_analysis_bigdataset = pd.read_csv(generalpop_ethereum_sentiment_analysis_bigdataset, encoding="utf-8-sig")
generalpop_ethereum_sentiment_analysis_bigdataset = generalpop_ethereum_sentiment_analysis_bigdataset.drop(columns=['Unnamed: 0'])
generalpop_ethereum_sentiment_analysis_bigdataset = generalpop_ethereum_sentiment_analysis_bigdataset.rename(columns={'text_compound': 'generalpop_ETH_text_compound'})
generalpop_ethereum_sentiment_analysis_bigdataset = generalpop_ethereum_sentiment_analysis_bigdataset.set_index('date')
generalpop_ethereum_sentiment_analysis_bigdataset
# Out:
#                                             user_name  \
# date
# 2021-11-15 07:26:39+00:00  #1 Crypto Currency TRADING
# 2021-11-15 07:26:35+00:00                      Reyrey
# 2021-11-15 07:26:32+00:00                 akter jahan
# 2021-11-15 07:26:30+00:00                       riyan
# 2021-11-15 07:26:30+00:00            Michelle Eriksen
# 2021-11-14 13:42:42+00:00  Hello guys! mind to view my project at opensea...
# 2021-11-14 13:42:31+00:00  Ethereum: One major misconception that will no...
# 2021-11-14 13:42:25+00:00  Giovanni Simeone bought for 0.238 ETH (1100.25...
#
#                            generalpop_ETH_text_compound  text_pos  text_neu  \
# date
# 2021-11-15 07:26:39+00:00                        0.0000     0.000     1.000
# 2021-11-15 07:26:35+00:00                        0.5983     0.145     0.855
# 2021-11-15 07:26:32+00:00                        0.6239     0.145     0.855
# 2021-11-15 07:26:30+00:00                        0.0000     0.000     1.000
# 2021-11-15 07:26:30+00:00                        0.0000     0.000     1.000
# ...                                                 ...       ...       ...
# 2021-11-14 13:43:00+00:00                        0.0000     0.000     1.000
# 2021-11-14 13:42:56+00:00                        0.3182     0.084     0.916
# 2021-11-14 13:42:42+00:00                        0.7170     0.150     0.850
# 2021-11-14 13:42:31+00:00                        0.0000     0.000     1.000
# 2021-11-14 13:42:25+00:00                        0.0000     0.000     1.000
#
#                            text_neg  text_sent
# date
# 2021-11-15 07:26:39+00:00       0.0          0
# 2021-11-15 07:26:35+00:00       0.0          1
# 2021-11-15 07:26:32+00:00       0.0          1
# 2021-11-15 07:26:30+00:00       0.0          0
# 2021-11-15 07:26:30+00:00       0.0          0
# ...                             ...        ...
# 2021-11-14 13:43:00+00:00       0.0          0
# 2021-11-14 13:42:56+00:00       0.0          1
# 2021-11-14 13:42:42+00:00       0.0          1
# 2021-11-14 13:42:31+00:00       0.0          0
# 2021-11-14 13:42:25+00:00       0.0          0
#
# [10000 rows x 12 columns]

# %%
# General Population DOGECOIN Tweet Sentiment Analysis

generalpop_DOGE_sentiment_analysis_bigdataset = Path("../Twitter_API/Twitter_API/Results/generalpop_DOGE_sentiment_analysis_bigdataset.csv")
generalpop_DOGE_sentiment_analysis_bigdataset = pd.read_csv(generalpop_DOGE_sentiment_analysis_bigdataset, encoding="utf-8-sig")
generalpop_DOGE_sentiment_analysis_bigdataset = generalpop_DOGE_sentiment_analysis_bigdataset.drop(columns=['language','hashtags','Unnamed: 0'])
generalpop_DOGE_sentiment_analysis_bigdataset = generalpop_DOGE_sentiment_analysis_bigdataset.rename(columns={'text_compound': 'generalpop_DOGE_text_compound'})
generalpop_DOGE_sentiment_analysis_bigdataset = generalpop_DOGE_sentiment_analysis_bigdataset.set_index('date')
generalpop_DOGE_sentiment_analysis_bigdataset
# Out:
#                 time  timezone        username  \
# date
# 20-04-2021  17:57:09       530     sunnyepposo
# 20-04-2021  17:57:07       530        pickndng
# 20-04-2021  17:57:07       530    s4y4n9_semu4
# 20-04-2021  17:57:06       530     dogecoinsky
# 20-04-2021  17:57:04       530     dogeman0401
# ...              ...       ...             ...
# 16-04-2021  06:01:13       530         rwied44
# 16-04-2021  06:01:12       530          rtx933
# 16-04-2021  06:01:12       530     grababagceo
# 16-04-2021  06:01:11       530    rizedogecoin
# 16-04-2021  06:01:10       530  thehandiimanaz
#
#                                            name  \
# date
# 20-04-2021                            congrats
# 20-04-2021  andrea || busy sa exams at pts kuno
# 20-04-2021                      #SayangiSemesta
# 20-04-2021                          dogecoinsky
# 20-04-2021                                  jay
# ...                                         ...
# 16-04-2021                           OutToLunch
# 16-04-2021                               rtx933
# 16-04-2021                        Brandon Jones
# 16-04-2021                      DogecoinRizing
# 16-04-2021                        youknowhowibe
#
#                                                         tweet  \
# date
# 20-04-2021  I invested16k couple weeks ago large trading g...
# 20-04-2021  Bought16k My dogecoin make millionaire Especia...
# 20-04-2021  I invested16k couple weeks ago large trading g...
# 20-04-2021  looking back 211 BTC low value high distrust h...
# 20-04-2021  Looks like hype today isnt coming fruition dog...
# ...                                                       ...
# 16-04-2021            dogecoin reaches 020 httpstcoyBkUBC3xRI
# 16-04-2021                dogecoin LATOKEN httpstcoCiR47MT9Qz
# 16-04-2021  dogecoin community unlike planet Thats were he...
# 16-04-2021                        Doge Prediction Up dogecoin
# 16-04-2021  BeefSuprem1776 Did read article To get1 get 55...
#
#             generalpop_DOGE_text_compound  text_pos  text_neu  text_neg  \
# date
# 20-04-2021                         0.0000     0.000     1.000     0.000
# 20-04-2021                        -0.4019     0.000     0.881     0.119
# 20-04-2021                         0.0000     0.000     1.000     0.000
# 20-04-2021                         0.5023     0.149     0.760     0.090
# 20-04-2021                         0.3612     0.200     0.800     0.000
# ...                                   ...       ...       ...       ...
# 16-04-2021                         0.0516     0.286     0.714     0.000
# 16-04-2021                         0.0000     0.000     1.000     0.000
# 16-04-2021                         0.0000     0.000     1.000     0.000
# 16-04-2021                         0.0000     0.000     1.000     0.000
# 16-04-2021                         0.0000     0.000     1.000     0.000
#
#             text_sent
# date
# 20-04-2021          0
# 20-04-2021         -1
# 20-04-2021          0
# 20-04-2021          1
# 20-04-2021          1
# ...               ...
# 16-04-2021          1
# 16-04-2021          0
# 16-04-2021          0
# 16-04-2021          0
# 16-04-2021          0
#
# [250009 rows x 10 columns]

# %%
# Bitcoin Price

bitcoin_price = Path("../crypto_data/BTCUSDT.csv")
bitcoin_price = pd.read_csv(bitcoin_price, encoding="utf-8-sig", header=[1])
bitcoin_price = bitcoin_price.drop(columns=['unix'])
bitcoin_price
# Out:
#                   date    symbol      open      high       low     close  \
# 0      10/04/2022 0:00  BTC/USDT  42753.96  42776.62  42653.68  42653.69
# 1      9/04/2022 23:00  BTC/USDT  42543.42  42800.00  42488.23  42753.97
# 2      9/04/2022 22:00  BTC/USDT  42558.06  42634.88  42501.31  42543.42
# 3      9/04/2022 21:00  BTC/USDT  42423.18  42584.49  42390.00  42558.06
# 4      9/04/2022 20:00  BTC/USDT  42511.95  42638.00  42423.18  42423.18
# ...                ...       ...       ...       ...       ...       ...
# 40699  17/08/2017 8:00  BTC/USDT   4349.99   4377.85   4333.32   4360.69
# 40700  17/08/2017 7:00  BTC/USDT   4324.35   4349.99   4287.41   4349.99
# 40701  17/08/2017 6:00  BTC/USDT   4315.32   4345.45   4309.37   4324.35
# 40702  17/08/2017 5:00  BTC/USDT   4308.83   4328.69   4291.37   4315.32
# 40703  17/08/2017 4:00  BTC/USDT  16199.91  16199.91   4261.32   4308.83
#
#        Volume BTC  Volume USDT  tradecount
# 0       547.32868  23374135.52     23134.0
# 1      1075.30723  45889601.98     30337.0
# 2       439.09087  18693342.59     18922.0
# 3       425.13616  18063585.63     19529.0
# 4       419.45489  17846424.65     21083.0
# ...           ...          ...         ...
# 40699     0.94990      4139.70         NaN
# 40700     4.44000     19241.06         NaN
# 40701     7.23000     31282.31         NaN
# 40702    23.23000    100304.82         NaN
# 40703    44.51000    190952.85         NaN
#
# [40704 rows x 9 columns]

# %%
# Google trends Data

googletrends_data = Path("../Google Trends/googletrends_data_results_v2.csv")
googletrends_data = pd.read_csv(googletrends_data, encoding="utf-8-sig")
googletrends_data = googletrends_data.rename(columns={'Unnamed: 0': 'date'})
googletrends_data = googletrends_data.drop(columns=['bitcoin_Close_x','ethereum_Close_x','tether_Close_x','bitcoin_Close_y','ethereum_Close_y',
                                                    'tether_Close_y', 'dogecoin_Close_x','dogecoin_Close_x']).rename(columns={'dogecoin_Close_y': 'dogecoin_Close'})
googletrends_data = googletrends_data.set_index('date')
googletrends_data
# Out:
#             bitcoin  ethereum  tether  dogecoin  usd coin  bitcoin_Close  \
# date
# 2017-11-09     10.0      13.0    29.0       0.0      12.0    7143.580078
# 2017-11-10     13.0      11.0    22.0       0.0      19.0    6618.140137
# 2017-11-11     12.0      10.0    24.0       0.0       8.0    6357.600098
# 2017-11-12     15.0      10.0    26.0       0.0      13.0    5950.069824
# 2017-11-13     12.0      10.0    20.0       0.0      13.0    6559.490234
# ...             ...       ...     ...       ...       ...            ...
# 2021-11-18     12.0      35.0    25.0       1.0      20.0   56942.136719
# 2021-11-19     11.0      32.0    29.0       1.0      15.0   58119.578125
# 2021-11-20     10.0      28.0    28.0       1.0      19.0   59697.195312
# 2021-11-21      9.0      24.0    29.0       1.0      14.0   58730.476562
# 2021-11-22     10.0      29.0    21.0       1.0      13.0   56289.289062
#
#             ethereum_Close  tether_Close  dogecoin_Close
# date
# 2017-11-09      320.884003      1.008180        0.001415
# 2017-11-10      299.252991      1.006010        0.001163
# 2017-11-11      314.681000      1.008990        0.001201
# 2017-11-12      307.907990      1.012470        0.001038
# 2017-11-13      316.716003      1.009350        0.001211
# ...                    ...           ...             ...
# 2021-11-18     4000.650879      0.999970        0.221383
# 2021-11-19     4298.306641      1.000820        0.233110
# 2021-11-20     4409.931152      1.000362        0.233024
# 2021-11-21     4269.732910      1.000873        0.226328
# 2021-11-22     4088.457764      1.000451        0.219676
#
# [1475 rows x 9 columns]

# %%
googletrends_data.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_e6660_row0_col0, #T_e6660_row1_col1, #T_e6660_row2_col2, #T_e6660_row3_col3, #T_e6660_row4_col4, #T_e6660_row5_col5, #T_e6660_row6_col6, #T_e6660_row7_col7, #T_e6660_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e6660_row0_col1 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_e6660_row0_col2 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_e6660_row0_col3 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_e6660_row0_col4 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_e6660_row0_col5, #T_e6660_row3_col5 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_e6660_row0_col6 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_e6660_row0_col7, #T_e6660_row5_col0, #T_e6660_row5_col4 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_e6660_row0_col8 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_e6660_row1_col0 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_e6660_row1_col2, #T_e6660_row3_col1 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_e6660_row1_col3 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_e6660_row1_col4 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_e6660_row1_col5, #T_e6660_row1_col6, #T_e6660_row8_col5 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_e6660_row1_col7 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_e6660_row1_col8 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_e6660_row2_col0 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_e6660_row2_col1, #T_e6660_row3_col8 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_e6660_row2_col3 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_e6660_row2_col4 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_e6660_row2_col5, #T_e6660_row4_col3 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_e6660_row2_col6 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_e6660_row2_col7 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_e6660_row2_col8 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_e6660_row3_col0 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_e6660_row3_col2 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_e6660_row3_col4 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_e6660_row3_col6 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_e6660_row3_col7 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_e6660_row4_col0 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_e6660_row4_col1 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_e6660_row4_col2 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_e6660_row4_col5 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_e6660_row4_col6 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_e6660_row4_col7 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_e6660_row4_col8 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_e6660_row5_col1, #T_e6660_row6_col1 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_e6660_row5_col2 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_e6660_row5_col3 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_e6660_row5_col6, #T_e6660_row6_col5 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_e6660_row5_col7, #T_e6660_row7_col0, #T_e6660_row7_col1, #T_e6660_row7_col2, #T_e6660_row7_col3, #T_e6660_row7_col4, #T_e6660_row7_col5, #T_e6660_row7_col6, #T_e6660_row7_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e6660_row5_col8 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_e6660_row6_col0 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_e6660_row6_col2 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_e6660_row6_col3 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_e6660_row6_col4 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_e6660_row6_col7 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_e6660_row6_col8, #T_e6660_row8_col6 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_e6660_row8_col0 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_e6660_row8_col1 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_e6660_row8_col2 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_e6660_row8_col3 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_e6660_row8_col4 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_e6660_row8_col7 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# </style>
# <table id="T_e6660_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >bitcoin</th>
#       <th class="col_heading level0 col1" >ethereum</th>
#       <th class="col_heading level0 col2" >tether</th>
#       <th class="col_heading level0 col3" >dogecoin</th>
#       <th class="col_heading level0 col4" >usd coin</th>
#       <th class="col_heading level0 col5" >bitcoin_Close</th>
#       <th class="col_heading level0 col6" >ethereum_Close</th>
#       <th class="col_heading level0 col7" >tether_Close</th>
#       <th class="col_heading level0 col8" >dogecoin_Close</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6660_level0_row0" class="row_heading level0 row0" >bitcoin</th>
#       <td id="T_e6660_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e6660_row0_col1" class="data row0 col1" >0.681792</td>
#       <td id="T_e6660_row0_col2" class="data row0 col2" >0.559934</td>
#       <td id="T_e6660_row0_col3" class="data row0 col3" >0.263496</td>
#       <td id="T_e6660_row0_col4" class="data row0 col4" >0.684247</td>
#       <td id="T_e6660_row0_col5" class="data row0 col5" >0.401314</td>
#       <td id="T_e6660_row0_col6" class="data row0 col6" >0.330643</td>
#       <td id="T_e6660_row0_col7" class="data row0 col7" >0.178717</td>
#       <td id="T_e6660_row0_col8" class="data row0 col8" >0.238270</td>
#     </tr>
#     <tr>
#       <th id="T_e6660_level0_row1" class="row_heading level0 row1" >ethereum</th>
#       <td id="T_e6660_row1_col0" class="data row1 col0" >0.681792</td>
#       <td id="T_e6660_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e6660_row1_col2" class="data row1 col2" >0.535095</td>
#       <td id="T_e6660_row1_col3" class="data row1 col3" >0.544466</td>
#       <td id="T_e6660_row1_col4" class="data row1 col4" >0.666441</td>
#       <td id="T_e6660_row1_col5" class="data row1 col5" >0.772555</td>
#       <td id="T_e6660_row1_col6" class="data row1 col6" >0.773080</td>
#       <td id="T_e6660_row1_col7" class="data row1 col7" >0.000054</td>
#       <td id="T_e6660_row1_col8" class="data row1 col8" >0.751746</td>
#     </tr>
#     <tr>
#       <th id="T_e6660_level0_row2" class="row_heading level0 row2" >tether</th>
#       <td id="T_e6660_row2_col0" class="data row2 col0" >0.559934</td>
#       <td id="T_e6660_row2_col1" class="data row2 col1" >0.535095</td>
#       <td id="T_e6660_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_e6660_row2_col3" class="data row2 col3" >0.253205</td>
#       <td id="T_e6660_row2_col4" class="data row2 col4" >0.519260</td>
#       <td id="T_e6660_row2_col5" class="data row2 col5" >0.266807</td>
#       <td id="T_e6660_row2_col6" class="data row2 col6" >0.321698</td>
#       <td id="T_e6660_row2_col7" class="data row2 col7" >-0.020157</td>
#       <td id="T_e6660_row2_col8" class="data row2 col8" >0.279193</td>
#     </tr>
#     <tr>
#       <th id="T_e6660_level0_row3" class="row_heading level0 row3" >dogecoin</th>
#       <td id="T_e6660_row3_col0" class="data row3 col0" >0.263496</td>
#       <td id="T_e6660_row3_col1" class="data row3 col1" >0.544466</td>
#       <td id="T_e6660_row3_col2" class="data row3 col2" >0.253205</td>
#       <td id="T_e6660_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_e6660_row3_col4" class="data row3 col4" >0.327698</td>
#       <td id="T_e6660_row3_col5" class="data row3 col5" >0.401836</td>
#       <td id="T_e6660_row3_col6" class="data row3 col6" >0.351935</td>
#       <td id="T_e6660_row3_col7" class="data row3 col7" >-0.035318</td>
#       <td id="T_e6660_row3_col8" class="data row3 col8" >0.482189</td>
#     </tr>
#     <tr>
#       <th id="T_e6660_level0_row

# %%
""" LINEAR REGRESSION """ 

import numpy as np
from sklearn.linear_model import LinearRegression

X = np.array(googletrends_data['ethereum']).reshape((-1,1))
y = np.array(googletrends_data['ethereum_Close'])
print(X)
print(y)
# Out:
# [[13.]
#  [11.]
#  [10.]
#  ...
#  [28.]
#  [24.]
#  [29.]]
# [ 320.88400269  299.25299072  314.68099976 ... 4409.93115234 4269.73291016
#  4088.45776367]

# %%
model = LinearRegression().fit(X, y)

# %%
r_sq = model.score(X, y)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# coefficient of determination: 0.5976527232469078
# intercept: 189.678986905334
# slope: [56.72325001]

# %%
import seaborn as sns
plt.rcParams.update({'font.size': 10})

sns.regplot(x=X, y=y, data=r_sq, logistic=False).set(title="Linear Regression Model on Google Tren Sentiment and Closing Price")
plt.ylabel('ETH Close Price')
plt.xlabel('ETH SVI')
# Out:
# Text(0.5, 0, 'ETH SVI')

# %%
from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(X, 
#                                                     y, 
#                                                     random_state=1, 
#                                                     stratify=y)
# X_train.shape

# train, xtest, ytrain, ytest = train_test_split(X, y, test_size=1/3,
#   random_state=85, stratify=y)

# X_train.shape

x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.33, random_state=42)

# %%
new_model = LinearRegression().fit(X, y.reshape((-1, 1)))
print('intercept:', new_model.intercept_)
print('slope:', new_model.coef_)
# Out:
# intercept: [189.67898691]
# slope: [[56.72325001]]

# %%
y_pred = model.predict(X)
print('predicted response:', y_pred, sep='\n')
# Out:
# predicted response:
# [ 927.08123698  813.63473697  756.91148696 ... 1777.92998707 1551.03698704
#  1834.65323707]

# %%
import matplotlib.pyplot as plt
plt.plot(y_pred)
plt.show()

# %%
LSTM_data = googletrends_data[['ethereum','ethereum_Close']].copy()
LSTM_data
# Out:
#             ethereum  ethereum_Close
# date
# 2017-11-09      13.0      320.884003
# 2017-11-10      11.0      299.252991
# 2017-11-11      10.0      314.681000
# 2017-11-12      10.0      307.907990
# 2017-11-13      10.0      316.716003
# ...              ...             ...
# 2021-11-18      35.0     4000.650879
# 2021-11-19      32.0     4298.306641
# 2021-11-20      28.0     4409.931152
# 2021-11-21      24.0     4269.732910
# 2021-11-22      29.0     4088.457764
#
# [1475 rows x 2 columns]

# %%
# This function accepts the column number for the features (X) and the target (y)
# It chunks the data up with a rolling window of Xt-n to predict Xt
# It returns a numpy array of X any y
def window_data(LSTM_data, window, feature_col_number, target_col_number):
    X = []
    y = []
    for i in range(len(LSTM_data) - window - 1):
        features = LSTM_data.iloc[i:(i + window), feature_col_number]
        target = LSTM_data.iloc[(i + window), target_col_number]
        X.append(features)
        y.append(target)
    return np.array(X), np.array(y).reshape(-1, 1)

# %%
# Predict Closing Prices using a 10 day window of previous closing prices
# Then, experiment with window sizes anywhere from 1 to 10 and see how the model performance changes
window_size = 10

# Column index 0 is the 'fng_value' column
# Column index 1 is the `Close` column
feature_column = 1
target_column = 1
X, y = window_data(LSTM_data, window_size, feature_column, target_column)

# %%
# Use 70% of the data for training and the remaineder for testing


seventypercent = int(.7 * len(X))

X_train = X[: seventypercent - 1]
y_train = y[: seventypercent - 1]

X_test = X[seventypercent:]
y_test = y[seventypercent:]

# %%
from sklearn.preprocessing import MinMaxScaler
# Use the MinMaxScaler to scale data between 0 and 1.


scaler = MinMaxScaler()
scaler.fit(X_train)
print(scaler.fit(X_train))
# Out:
# MinMaxScaler()

# %%
""" Transform the train and test data """


scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

scaler.fit(y_train)

y_train = scaler.transform(y_train)
y_test = scaler.transform(y_test)

# %%
# Reshape the features for the model

X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
# Predicting y using x
predictions = model.predict(X)

# Evaluating the model
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score

# R2 score
score = model.score(X, y)
r2 = r2_score(y, predictions)

# MSE
mse = mean_squared_error(y, predictions)
# RMSE
rmse = np.sqrt(mse)

# Standard deviation of variable
np.std(y)

# Plotting
plt.scatter(X["Week_of_year"], y)
plt.plot(X["Week_of_Year"], predictions, color = "red")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12164/4064354124.py in <module>
#       1 # Predicting y using x
# ----> 2 predictions = model.predict(X)
#       3
#       4 # Evaluating the model
#       5
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     343         check_is_fitted(self)
#     344
# --> 345         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     346         return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     347
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     583
#     584         if not no_val_X and check_params.get("ensure_2d", True):
# --> 585             self._check_n_features(X, reset=reset)
#     586
#     587         return out
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _check_n_features(self, X, reset)
#     398
#     399         if n_features != self.n_features_in_:
# --> 400             raise ValueError(
#     401                 f"X has {n_features} features, but {self.__class__.__name__} "
#     402                 f"is expecting {self.n_features_in_} features as input."
#
# ValueError: X has 10 features, but LinearRegression is expecting 1 features as input.

# %%
""" MULTIPLE/LINEAR REGRESSION """

from sklearn.linear_model import LinearRegression

y = googletrends_data['bitcoin_Close']
X = googletrends_data['bitcoin']


# Create the linear regression model
model = LinearRegression()

# Fit the model to the data
model.fit(X, y)

# %%
# CONCAT Dataframes for final analysis

combinded_data = pd.concat([generalpop_DOGE_sentiment_analysis_bigdataset,googletrends_data])
combinded_data

# %%
""" MULTIPLE/LINEAR REGRESSION """

from sklearn.linear_model import LinearRegression

# Create the linear regression model
model = LinearRegression()

# Fit the model to the data
model.fit(X_binary_encoded, y)

# %%
# Predicting y using x
predictions = model.predict(X_binary_encoded)

# Evaluating the model

import numpy as np
from sklearn.metrics import mean_squared_error, r2_score

# R2 score
score = model.score(X_binary_encoded, y)
r2 = r2_score(y, predictions)

# MSE
mse = mean_squared_error(y, predictions)
# RMSE
rmse = np.sqrt(mse)

# Standard deviation of variable
np.std(y)

# Plotting
plt.scatter(X["Week_of_year"], y)
plt.plot(X["Week_of_Year"], predictions, color = "red")
